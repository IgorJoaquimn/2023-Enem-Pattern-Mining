# %%
from mlxtend.frequent_patterns import apriori,fpgrowth
# Convert your data to a one-hot encoded DataFrame
from mlxtend.frequent_patterns import association_rules
import pandas as pd
import numpy as np
from mlxtend.preprocessing import TransactionEncoder

# %%
PATH_PROCESSED = "dados_processados/"

# %%
df = pd.read_csv(PATH_PROCESSED + "itemsets.csv").dropna()

# %%
def string_to_list(row):
    return row.split(";")

# %%
dataset = df["TX_RESPOSTAS_CN_WRONG"].apply(string_to_list)

# %%
te = TransactionEncoder()
te_ary = te.fit(dataset).transform(dataset)

# %%
df2 = pd.DataFrame(te_ary, columns=te.columns_)

# %%
frequent_itemsets = apriori(df2, min_support=0.1,use_colnames=True)

# %%
association_rules(frequent_itemsets, metric="lift", min_threshold=0.7)
# Out:
#        antecedents     consequents  antecedent support  consequent support  \
# 0           (Q1-A)         (Q10-B)            0.354317            0.328057
# 1          (Q10-B)          (Q1-A)            0.328057            0.354317
# 2           (Q1-A)         (Q14-E)            0.354317            0.412152
# 3          (Q14-E)          (Q1-A)            0.412152            0.354317
# 4           (Q1-A)         (Q15-A)            0.354317            0.325038
# ..             ...             ...                 ...                 ...
# 909  (Q40-C, Q9-A)         (Q41-C)            0.199013            0.466322
# 910  (Q9-A, Q41-C)         (Q40-C)            0.239457            0.385910
# 911        (Q40-C)   (Q9-A, Q41-C)            0.385910            0.239457
# 912        (Q41-C)   (Q40-C, Q9-A)            0.466322            0.199013
# 913         (Q9-A)  (Q40-C, Q41-C)            0.474927            0.210789
#
#       support  confidence      lift  leverage  conviction  zhangs_metric
# 0    0.118713    0.335046  1.021305  0.002476    1.010511       0.032307
# 1    0.118713    0.361866  1.021305  0.002476    1.011829       0.031045
# 2    0.159556    0.450320  1.092606  0.013524    1.069437       0.131268
# 3    0.159556    0.387129  1.092606  0.013524    1.053538       0.144182
# 4    0.122595    0.346003  1.064501  0.007428    1.032057       0.093842
# ..        ...         ...       ...       ...         ...            ...
# 909  0.115341    0.579566  1.242844  0.022537    1.269349       0.243941
# 910  0.115341    0.481678  1.248161  0.022932    1.184765       0.261421
# 911  0.115341    0.298881  1.248161  0.022932    1.084756       0.323766
# 912  0.115341    0.247342  1.242844  0.022537    1.064211       0.366127
# 913  0.115341    0.242861  1.152151  0.015232    1.042359       0.251504
#
# [914 rows x 10 columns]
